# %%
import time
import random
import logging
import csv
import json
import re
from urllib.parse import urljoin, urlparse, parse_qs, urlencode
from typing import List, Dict, Optional, Set
import requests
from bs4 import BeautifulSoup

# vinted_scraper.py
# Requires: requests, bs4
# Optional: selenium (if dynamic rendering required)


# Reuse notebook variables if present
BASE_URL = 'https://www.vinted.fr'
START_URL = f'{BASE_URL}/vetements?search_text=jean'
USER_AGENT = 'Mozilla/5.0 (compatible; VintedScraper/1.0; +https://example.com/bot)'
session = requests.Session()
session.headers.update({'User-Agent': USER_AGENT})
rp = None
REQUEST_DELAY = (0.5, 1.5)  # Min and max delay between requests in seconds
MAX_PAGES = 2
LOG_LEVEL = 20
OUTPUT_CSV = 'vinted_products.csv'
OUTPUT_JSONL = 'vinted_products.jsonl'

logging.basicConfig(level=LOG_LEVEL, format='%(asctime)s %(levelname)s %(message)s')
logger = logging.getLogger(__name__)
session.headers.update({'User-Agent': USER_AGENT})

# %%
import os

def polite_get(url: str, timeout: int = 15) -> Optional[requests.Response]:
    try:
        resp = session.get(url, timeout=timeout)
        if resp.status_code == 200:
            time.sleep(random.uniform(*REQUEST_DELAY))
            return resp
        logger.warning("GET %s -> status %s", url, resp.status_code)
    except Exception as e:
        logger.exception("Request failed: %s", e)
    return None


def make_page_url(base: str, page: int) -> str:
    """Add or replace page param in a URL's query string."""
    parsed = urlparse(base)
    qs = parse_qs(parsed.query)
    qs['page'] = [str(page)]
    new_query = urlencode({k: v[0] for k, v in qs.items()})
    return parsed._replace(query=new_query).geturl()


PRODUCT_URL_PATTERNS = [r'/items/', r'/item/', r'/v/', r'/listing/']


def looks_like_product(href: str) -> bool:
    if not href:
        return False
    parsed = urlparse(href)
    path = parsed.path
    for p in PRODUCT_URL_PATTERNS:
        if re.search(p, path):
            return True
    return False


def extract_links_from_listing(html: str) -> Set[str]:
    soup = BeautifulSoup(html, 'html.parser')
    links = set()
    for a in soup.find_all('a', href=True):
        href = a['href']
        # normalize relative URLs
        full = urljoin(BASE_URL, href)
        if looks_like_product(full):
            # strip fragment and query params that aren't needed
            u = full.split('#')[0]
            links.add(u)
    return links


def parse_product_page(html: str, url: str) -> Dict:
    soup = BeautifulSoup(html, 'html.parser')
    data = {'url': url}

    # Try JSON-LD first
    try:
        for script in soup.find_all('script', type='application/ld+json'):
            try:
                j = json.loads(script.string or '')
            except Exception:
                continue
            # j might be a list
            items = j if isinstance(j, list) else [j]
            for item in items:
                if isinstance(item, dict) and item.get('@type', '').lower() == 'product':
                    data['title'] = item.get('name') or data.get('title')
                    data['description'] = item.get('description') or data.get('description')
                    images = item.get('image')
                    if isinstance(images, list):
                        data['images'] = images
                    elif isinstance(images, str):
                        data['images'] = [images]
                    offers = item.get('offers') or {}
                    if isinstance(offers, dict):
                        data['price'] = offers.get('price')
                        data['currency'] = offers.get('priceCurrency')
                    # found JSON-LD product; good enough
                    break
            if 'title' in data:
                break
    except Exception:
        logger.debug("JSON-LD parse error", exc_info=True)

    # Fallback to meta tags
    if 'title' not in data:
        og_title = soup.find('meta', property='og:title')
        if og_title and og_title.get('content'):
            data['title'] = og_title['content']
    if 'description' not in data:
        og_desc = soup.find('meta', property='og:description')
        if og_desc and og_desc.get('content'):
            data['description'] = og_desc['content']
    if 'images' not in data:
        og_image = soup.find('meta', property='og:image')
        if og_image and og_image.get('content'):
            data['images'] = [og_image['content']]

    # price meta
    if 'price' not in data:
        price_meta = soup.find('meta', attrs={'property': 'product:price:amount'})
        if price_meta and price_meta.get('content'):
            data['price'] = price_meta['content']
    if 'currency' not in data:
        cur_meta = soup.find('meta', attrs={'property': 'product:price:currency'})
        if cur_meta and cur_meta.get('content'):
            data['currency'] = cur_meta['content']

    # Extract textual details heuristically
    try:
        # item id from url digits
        m = re.search(r'(\d{4,})', url)
        if m:
            data['item_id'] = m.group(1)
    except Exception:
        pass

    # images from gallery
    imgs = []
    for img in soup.select('img'):
        src = img.get('src') or img.get('data-src') or img.get('data-lazy-src')
        if src and src.startswith('http'):
            imgs.append(src)
    if imgs:
        data.setdefault('images', imgs)

    # Seller info heuristics
    seller = {}
    seller_a = soup.find('a', href=re.compile(r'/membre/|/member/'))
    if seller_a:
        seller['name'] = seller_a.get_text(strip=True)
        seller['url'] = urljoin(BASE_URL, seller_a['href'])
    if seller:
        data['seller'] = seller

    # Additional fields by selectors (best-effort)
    # price text
    if 'price' not in data:
        price_el = soup.select_one('[data-testid="price"], .price, .ProductPrice, .item-price')
        if price_el:
            data['price'] = price_el.get_text(strip=True)
    # size, brand, condition - try to find label/value pairs
    attrs = {}
    for li in soup.select('.item-attributes li, .details-list li, .CharacteristicList li'):
        txt = li.get_text(separator=' ', strip=True)
        if ':' in txt:
            k, v = txt.split(':', 1)
            attrs[k.strip().lower()] = v.strip()
    if attrs:
        data.setdefault('attributes', attrs)

    data['scraped_at'] = time.strftime('%Y-%m-%dT%H:%M:%SZ', time.gmtime())
    return data


def save_results(items: List[Dict], csv_path: str = OUTPUT_CSV, jsonl_path: str = OUTPUT_JSONL): # a modifier
    # JSONL
    with open(jsonl_path, 'w', encoding='utf-8') as f:
        for it in items:
            f.write(json.dumps(it, ensure_ascii=False) + '\n')


def scrape_vinted(start_url: str = START_URL, max_pages: int = MAX_PAGES) -> List[Dict]:
    all_products = []
    seen_urls = set()
    # Load previously scraped product URLs (if any) so we don't re-fetch them
    jsonl_path = "vinted_products.jsonl"
    try:
        if os.path.exists(jsonl_path):
            loaded = 0
            with open(jsonl_path, 'r', encoding='utf-8') as f:
                for line in f:
                    try:
                        obj = json.loads(line)
                        u = obj.get('url')
                        if u:
                            seen_urls.add(u)
                            loaded += 1
                    except Exception:
                        continue
            logger.info("Loaded %d previously scraped URLs from %s", loaded, jsonl_path)
    except Exception:
        logger.exception("Failed loading existing URLs from %s", jsonl_path)

    # keep the start listing URL marked as seen (won't be treated as a product link)
    seen_urls.add(start_url)
    for page in range(1, max_pages + 1):
        page_url = make_page_url(start_url, page)
        logger.info("Fetching listing page %d: %s", page, page_url)
        time.sleep(random.uniform(*REQUEST_DELAY)*5)
        resp = polite_get(page_url)
        if not resp:
            logger.info("Stopping: failed to fetch page %d", page)
            break
        links = extract_links_from_listing(resp.text)
        links = [l for l in links if l not in seen_urls]
        logger.info("Found %d new product links on page %d", len(links), page)
        if not links:
            # nothing new, stop
            break
        for prod_url in links:
            seen_urls.add(prod_url)
            logger.info("Fetching product: %s", prod_url)
            presp = polite_get(prod_url)
            if not presp:
                logger.warning("Failed product fetch: %s", prod_url)
                continue
            pdata = parse_product_page(presp.text, prod_url)
            all_products.append(pdata)
        # quick stop if reached many products (optional)
    logger.info("Scraped %d products", len(all_products))
    return all_products

# %%
items = scrape_vinted()
save_results(items)
logger.info("Saved %d items to %s and %s", len(items), OUTPUT_CSV, OUTPUT_JSONL)
# Out:
# 2025-12-30 16:16:34,297 INFO Fetching listing page 1: https://www.vinted.fr/vetements?search_text=jean&page=1
# 2025-12-30 16:16:43,069 INFO Found 96 new product links on page 1
# 2025-12-30 16:16:43,070 INFO Fetching product: https://www.vinted.fr/items/7839067742-jean-noir-grain-de-malice-taille-42?referrer=catalog
# 2025-12-30 16:16:44,880 INFO Fetching product: https://www.vinted.fr/items/7838782029-jean-noir?referrer=catalog
# 2025-12-30 16:16:47,452 INFO Fetching product: https://www.vinted.fr/items/7839760247-jean-taille-basse-large?referrer=catalog
# 2025-12-30 16:16:49,213 INFO Fetching product: https://www.vinted.fr/items/7839782042-pantalon-jean?referrer=catalog
# 2025-12-30 16:16:51,022 INFO Fetching product: https://www.vinted.fr/items/7840087017-pantalon?referrer=catalog
# 2025-12-30 16:16:52,952 INFO Fetching product: https://www.vinted.fr/items/7840660491-jean-large?referrer=catalog
# 2025-12-30 16:16:54,854 INFO Fetching product: https://www.vinted.fr/items/7840687469-jean?referrer=catalog
# 2025-12-30 16:16:56,309 INFO Fetching product: https://www.vinted.fr/items/7839834690-jean-homme?referrer=catalog
# 2025-12-30 16:16:58,802 INFO Fetching product: https://www.vinted.fr/items/7840399506-jean-taille-basse-vintage?referrer=catalog
# 2025-12-30 16:17:00,433 INFO Fetching product: https://www.vinted.fr/items/7839610664-jean-zara?referrer=catalog
# 2025-12-30 16:17:02,079 INFO Fetching product: https://www.vinted.fr/items/7839114882-jeans-bleu-mango-taille-xs346?referrer=catalog
# 2025-12-30 16:17:03,834 INFO Fetching product: https://www.vinted.fr/items/7839049279-jean-droit-hm?referrer=catalog
# 2025-12-30 16:17:06,066 INFO Fetching product: https://www.vinted.fr/items/7839671793-jean-bleu-zara?referrer=catalog
# 2025-12-30 16:17:09,114 INFO Fetching product: https://www.vinted.fr/items/7838472273-jeans-pimkie?referrer=catalog
# 2025-12-30 16:17:12,772 INFO Fetching product: https://www.vinted.fr/items/7840853580-jean-wide-kiabi?referrer=catalog
# 2025-12-30 16:17:14,943 INFO Fetching product: https://www.vinted.fr/items/7839993693-jean-d92-stradivarius-en-taille-36?referrer=catalog
# 2025-12-30 16:17:16,740 INFO Fetching product: https://www.vinted.fr/items/7839182030-jean-la-mode-est-a-vous?referrer=catalog
# 2025-12-30 16:17:19,514 INFO Fetching product: https://www.vinted.fr/items/7839512434-jean-large-confortable-zara?referrer=catalog
# 2025-12-30 16:17:22,565 INFO Fetching product: https://www.vinted.fr/items/7840860507-jean-zara?referrer=catalog
# 2025-12-30 16:17:25,167 INFO Fetching product: https://www.vinted.fr/items/7838898533-pantalon-jean?referrer=catalog
# 2025-12-30 16:17:28,283 INFO Fetching product: https://www.vinted.fr/items/7839662316-western-pants-slight-flare?referrer=catalog
# 2025-12-30 16:17:31,900 INFO Fetching product: https://www.vinted.fr/items/7839709258-jean-taille-basse?referrer=catalog
# 2025-12-30 16:17:35,102 INFO Fetching product: https://www.vinted.fr/items/7838903354-jean-clair?referrer=catalog
# 2025-12-30 16:17:37,969 INFO Fetching product: https://www.vinted.fr/items/7839423679-jeans-beige-maison-123-taille-44?referrer=catalog
# 2025-12-30 16:17:40,174 INFO Fetching product: https://www.vinted.fr/items/7839178572-jean-rose-avec-poche-en-forme-de-coeur?referrer=catalog
# 2025-12-30 16:17:42,053 INFO Fetching product: https://www.vinted.fr/items/7840064123-jean-fraises?referrer=catalog
# 2025-12-30 16:17:44,094 INFO Fetching product: https://www.vinted.fr/items/7839118954-jeans?referrer=catalog
# 2025-12-30 16:17:45,880 INFO Fetching product: https://www.vinted.fr/items/7838891807-jean-noir-t34-morgan?referrer=catalog
# 2025-12-30 16:17:49,139 INFO Fetching product: https://www.vinted.fr/items/7839729733-jeans-bleu?referrer=catalog
# 2025-12-30 16:17:51,021 INFO Fetching product: https://www.vinted.fr/items/7839903077-jean-rose?referrer=catalog
# 2025-12-30 16:17:52,382 INFO Fetching product: https://www.vinted.fr/items/7839739860-jeans-bleu?referrer=catalog
# 2025-12-30 16:17:54,249 INFO Fetching product: https://www.vinted.fr/items/7838963683-jeans?referrer=catalog
# 2025-12-30 16:17:55,786 INFO Fetching product: https://www.vinted.fr/items/7839929614-jean-a-paillettes?referrer=catalog
# 2025-12-30 16:17:57,482 INFO Fetching product: https://www.vinted.fr/items/7834291078-jean-gris-fonce?referrer=catalog
# 2025-12-30 16:17:59,289 INFO Fetching product: https://www.vinted.fr/items/7840069325-jean-flare-patte-delephant-fonce?referrer=catalog
# 2025-12-30 16:17:59,579 WARNING GET https://www.vinted.fr/items/7840069325-jean-flare-patte-delephant-fonce?referrer=catalog -> status 429
# 2025-12-30 16:17:59,581 WARNING Failed product fetch: https://www.vinted.fr/items/7840069325-jean-flare-patte-delephant-fonce?referrer=catalog
# 2025-12-30 16:17:59,583 INFO Fetching product: https://www.vinted.fr/items/7839311888-jean-coupe-droite?referrer=catalog
# 2025-12-30 16:17:59,784 WARNING GET https://www.vinted.fr/items/7839311888-jean-coupe-droite?referrer=catalog -> status 429
# 2025-12-30 16:17:59,786 WARNING Failed product fetch: https://www.vinted.fr/items/7839311888-jean-coupe-droite?referrer=catalog
# 2025-12-30 16:17:59,790 INFO Fetching product: https://www.vinted.fr/items/7840337185-jean-y2k-betty-boo-coupe-evasee-style-streetwear-taille-m?referrer=catalog
# 2025-12-30 16:17:59,945 WARNING GET https://www.vinted.fr/items/7840337185-jean-y2k-betty-boo-coupe-evasee-style-streetwear-taille-m?referrer=catalog -> status 429
# 2025-12-30 16:17:59,948 WARNING Failed product fetch: https://www.vinted.fr/items/7840337185-jean-y2k-betty-boo-coupe-evasee-style-streetwear-taille-m?referrer=catalog
# 2025-12-30 16:17:59,950 INFO Fetching product: https://www.vinted.fr/items/7839090337-pantacourt-en-jean-bleu-4-ans-motif-papillon-vynil-fraise?referrer=catalog
# 2025-12-30 16:18:00,094 WARNING GET https://www.vinted.fr/items/7839090337-pantacourt-en-jean-bleu-4-ans-motif-papillon-vynil-fraise?referrer=catalog -> status 429
# 2025-12-30 16:18:00,096 WARNING Failed product fetch: https://www.vinted.fr/items/7839090337-pantacourt-en-jean-bleu-4-ans-motif-papillon-vynil-fraise?referrer=catalog
# 2025-12-30 16:18:00,097 INFO Fetching product: https://www.vinted.fr/items/7840548647-jean-large-cache-cache-vert?referrer=catalog
# 2025-12-30 16:18:00,252 WARNING GET https://www.vinted.fr/items/7840548647-jean-large-cache-cache-vert?referrer=catalog -> status 429
# 2025-12-30 16:18:00,254 WARNING Failed product fetch: https://www.vinted.fr/items/7840548647-jean-large-cache-cache-vert?referrer=catalog
# 2025-12-30 16:18:00,257 INFO Fetching product: https://www.vinted.fr/items/7840046264-jean-pull-and-bear?referrer=catalog
# 2025-12-30 16:18:00,442 WARNING GET https://www.vinted.fr/items/7840046264-jean-pull-and-bear?referrer=catalog -> status 429
# 2025-12-30 16:18:00,444 WARNING Failed product fetch: https://www.vinted.fr/items/7840046264-jean-pull-and-bear?referrer=catalog
# 2025-12-30 16:18:00,445 INFO Fetching product: https://www.vinted.fr/items/7839507694-pantalon?referrer=catalog
# 2025-12-30 16:18:02,479 INFO Fetching product: https://www.vinted.fr/items/7840069357-jean-taille-haute?referrer=catalog
# 2025-12-30 16:18:04,940 INFO Fetching product: https://www.vinted.fr/items/7838874905-jean-femme?referrer=catalog
# 2025-12-30 16:18:06,967 INFO Fetching product: https://www.vinted.fr/items/7840860676-jean-baggy-taille-basse-vintage?referrer=catalog
# 2025-12-30 16:18:09,379 INFO Fetching product: https://www.vinted.fr/items/7839855775-jolie-jeans-gris-jambe-large-taille-40?referrer=catalog
# 2025-12-30 16:18:11,610 INFO Fetching product: https://www.vinted.fr/items/7839554823-jean-vintage-y2k?referrer=catalog
# 2025-12-30 16:18:13,503 INFO Fetching product: https://www.vinted.fr/items/7839637130-jean-gris-baggy?referrer=catalog
# 2025-12-30 16:18:15,394 INFO Fetching product: https://www.vinted.fr/items/7840441928-lot-2-jeans?referrer=catalog
# 2025-12-30 16:18:17,187 INFO Fetching product: https://www.vinted.fr/items/7839521518-jean-large?referrer=catalog
# 2025-12-30 16:18:18,985 INFO Fetching product: https://www.vinted.fr/items/7840093499-baggy-new-yorker-bleu-marine?referrer=catalog
# 2025-12-30 16:18:20,792 INFO Fetching product: https://www.vinted.fr/items/7839449091-jean-complices-34?referrer=catalog
# 2025-12-30 16:18:22,928 INFO Fetching product: https://www.vinted.fr/items/7839167512-jean-promod?referrer=catalog
# 2025-12-30 16:18:25,086 INFO Fetching product: https://www.vinted.fr/items/7839724213-jean-stradivarius?referrer=catalog
# 2025-12-30 16:18:26,885 INFO Fetching product: https://www.vinted.fr/items/7840224481-jeans-levis-504?referrer=catalog
# 2025-12-30 16:18:30,292 INFO Fetching product: https://www.vinted.fr/items/7838663037-pantalon-gris-fonce?referrer=catalog
# 2025-12-30 16:18:33,296 INFO Fetching product: https://www.vinted.fr/items/7839763705-jean-bleu-marine?referrer=catalog
# 2025-12-30 16:18:34,795 INFO Fetching product: https://www.vinted.fr/items/7838919636-jean-flare-hm?referrer=catalog
# 2025-12-30 16:18:35,027 WARNING GET https://www.vinted.fr/items/7838919636-jean-flare-hm?referrer=catalog -> status 429
# 2025-12-30 16:18:35,029 WARNING Failed product fetch: https://www.vinted.fr/items/7838919636-jean-flare-hm?referrer=catalog
# 2025-12-30 16:18:35,030 INFO Fetching product: https://www.vinted.fr/items/7839108599-jeans-d98-stradivarius?referrer=catalog
# 2025-12-30 16:18:35,193 WARNING GET https://www.vinted.fr/items/7839108599-jeans-d98-stradivarius?referrer=catalog -> status 429
# 2025-12-30 16:18:35,194 WARNING Failed product fetch: https://www.vinted.fr/items/7839108599-jeans-d98-stradivarius?referrer=catalog
# 2025-12-30 16:18:35,195 INFO Fetching product: https://www.vinted.fr/items/7838775960-jean-large-bleu?referrer=catalog
# 2025-12-30 16:18:35,481 WARNING GET https://www.vinted.fr/items/7838775960-jean-large-bleu?referrer=catalog -> status 429
# 2025-12-30 16:18:35,483 WARNING Failed product fetch: https://www.vinted.fr/items/7838775960-jean-large-bleu?referrer=catalog
# 2025-12-30 16:18:35,484 INFO Fetching product: https://www.vinted.fr/items/7839421788-a-vendre-jean-zara?referrer=catalog
# 2025-12-30 16:18:35,781 WARNING GET https://www.vinted.fr/items/7839421788-a-vendre-jean-zara?referrer=catalog -> status 429
# 2025-12-30 16:18:35,782 WARNING Failed product fetch: https://www.vinted.fr/items/7839421788-a-vendre-jean-zara?referrer=catalog
# 2025-12-30 16:18:35,783 INFO Fetching product: https://www.vinted.fr/items/7839075244-jean-morgan?referrer=catalog
# 2025-12-30 16:18:35,923 WARNING GET https://www.vinted.fr/items/7839075244-jean-morgan?referrer=catalog -> status 429
# 2025-12-30 16:18:35,925 WARNING Failed product fetch: https://www.vinted.fr/items/7839075244-jean-morgan?referrer=catalog
# 2025-12-30 16:18:35,927 INFO Fetching product: https://www.vinted.fr/items/7840359493-jean-taille-basse-zara?referrer=catalog
# 2025-12-30 16:18:36,056 WARNING GET https://www.vinted.fr/items/7840359493-jean-taille-basse-zara?referrer=catalog -> status 429
# 2025-12-30 16:18:36,058 WARNING Failed product fetch: https://www.vinted.fr/items/7840359493-jean-taille-basse-zara?referrer=catalog
# 2025-12-30 16:18:36,059 INFO Fetching product: https://www.vinted.fr/items/7839180340-jean-large-baggy-style-y2k-denim-bleu-brut-coupe-droite?referrer=catalog
# 2025-12-30 16:18:36,178 WARNING GET https://www.vinted.fr/items/7839180340-jean-large-baggy-style-y2k-denim-bleu-brut-coupe-droite?referrer=catalog -> status 429
# 2025-12-30 16:18:36,179 WARNING Failed product fetch: https://www.vinted.fr/items/7839180340-jean-large-baggy-style-y2k-denim-bleu-brut-coupe-droite?referrer=catalog
# 2025-12-30 16:18:36,181 INFO Fetching product: https://www.vinted.fr/items/7839078635-jean-taille-34?referrer=catalog
# 2025-12-30 16:18:36,299 WARNING GET https://www.vinted.fr/items/7839078635-jean-taille-34?referrer=catalog -> status 429
# 2025-12-30 16:18:36,300 WARNING Failed product fetch: https://www.vinted.fr/items/7839078635-jean-taille-34?referrer=catalog
# 2025-12-30 16:18:36,301 INFO Fetching product: https://www.vinted.fr/items/7840730911-jean-oversize-shein?referrer=catalog
# 2025-12-30 16:18:36,423 WARNING GET https://www.vinted.fr/items/7840730911-jean-oversize-shein?referrer=catalog -> status 429
# 2025-12-30 16:18:36,425 WARNING Failed product fetch: https://www.vinted.fr/items/7840730911-jean-oversize-shein?referrer=catalog
# 2025-12-30 16:18:36,427 INFO Fetching product: https://www.vinted.fr/items/7840607327-jean-bleu-zara?referrer=catalog
# 2025-12-30 16:18:36,541 WARNING GET https://www.vinted.fr/items/7840607327-jean-bleu-zara?referrer=catalog -> status 429
# 2025-12-30 16:18:36,542 WARNING Failed product fetch: https://www.vinted.fr/items/7840607327-jean-bleu-zara?referrer=catalog
# 2025-12-30 16:18:36,544 INFO Fetching product: https://www.vinted.fr/items/7839607592-jean-skinny?referrer=catalog
# 2025-12-30 16:18:36,661 WARNING GET https://www.vinted.fr/items/7839607592-jean-skinny?referrer=catalog -> status 429
# 2025-12-30 16:18:36,662 WARNING Failed product fetch: https://www.vinted.fr/items/7839607592-jean-skinny?referrer=catalog
# 2025-12-30 16:18:36,663 INFO Fetching product: https://www.vinted.fr/items/7839723923-ensemble-en-jean?referrer=catalog
# 2025-12-30 16:18:36,897 WARNING GET https://www.vinted.fr/items/7839723923-ensemble-en-jean?referrer=catalog -> status 429
# 2025-12-30 16:18:36,899 WARNING Failed product fetch: https://www.vinted.fr/items/7839723923-ensemble-en-jean?referrer=catalog
# 2025-12-30 16:18:36,901 INFO Fetching product: https://www.vinted.fr/items/7839548709-jean-droit?referrer=catalog
# 2025-12-30 16:18:37,037 WARNING GET https://www.vinted.fr/items/7839548709-jean-droit?referrer=catalog -> status 429
# 2025-12-30 16:18:37,039 WARNING Failed product fetch: https://www.vinted.fr/items/7839548709-jean-droit?referrer=catalog
# 2025-12-30 16:18:37,041 INFO Fetching product: https://www.vinted.fr/items/7839082360-pantalon-large-fille-10-ans?referrer=catalog
# 2025-12-30 16:18:37,160 WARNING GET https://www.vinted.fr/items/7839082360-pantalon-large-fille-10-ans?referrer=catalog -> status 429
# 2025-12-30 16:18:37,162 WARNING Failed product fetch: https://www.vinted.fr/items/7839082360-pantalon-large-fille-10-ans?referrer=catalog
# 2025-12-30 16:18:37,164 INFO Fetching product: https://www.vinted.fr/items/7838919930-low-waist-bootcut-jeans?referrer=catalog
# 2025-12-30 16:18:37,295 WARNING GET https://www.vinted.fr/items/7838919930-low-waist-bootcut-jeans?referrer=catalog -> status 429
# 2025-12-30 16:18:37,297 WARNING Failed product fetch: https://www.vinted.fr/items/7838919930-low-waist-bootcut-jeans?referrer=catalog
# 2025-12-30 16:18:37,298 INFO Fetching product: https://www.vinted.fr/items/7838830408-djinn-large?referrer=catalog
# 2025-12-30 16:18:37,409 WARNING GET https://www.vinted.fr/items/7838830408-djinn-large?referrer=catalog -> status 429
# 2025-12-30 16:18:37,411 WARNING Failed product fetch: https://www.vinted.fr/items/7838830408-djinn-large?referrer=catalog
# 2025-12-30 16:18:37,412 INFO Fetching product: https://www.vinted.fr/items/7839924182-jean-mom?referrer=catalog
# 2025-12-30 16:18:37,527 WARNING GET https://www.vinted.fr/items/7839924182-jean-mom?referrer=catalog -> status 429
# 2025-12-30 16:18:37,529 WARNING Failed product fetch: https://www.vinted.fr/items/7839924182-jean-mom?referrer=catalog
# 2025-12-30 16:18:37,530 INFO Fetching product: https://www.vinted.fr/items/7838782079-jeans-elastici?referrer=catalog
# 2025-12-30 16:18:38,291 WARNING GET https://www.vinted.fr/items/7838782079-jeans-elastici?referrer=catalog -> status 429
# 2025-12-30 16:18:38,293 WARNING Failed product fetch: https://www.vinted.fr/items/7838782079-jeans-elastici?referrer=catalog
# 2025-12-30 16:18:38,294 INFO Fetching product: https://www.vinted.fr/items/7840556095-jean-bleu?referrer=catalog
# 2025-12-30 16:18:38,540 WARNING GET https://www.vinted.fr/items/7840556095-jean-bleu?referrer=catalog -> status 429
# 2025-12-30 16:18:38,542 WARNING Failed product fetch: https://www.vinted.fr/items/7840556095-jean-bleu?referrer=catalog
# 2025-12-30 16:18:38,544 INFO Fetching product: https://www.vinted.fr/items/7839735377-jeans-mango-femme?referrer=catalog
# 2025-12-30 16:18:38,703 WARNING GET https://www.vinted.fr/items/7839735377-jeans-mango-femme?referrer=catalog -> status 429
# 2025-12-30 16:18:38,705 WARNING Failed product fetch: https://www.vinted.fr/items/7839735377-jeans-mango-femme?referrer=catalog
# 2025-12-30 16:18:38,707 INFO Fetching product: https://www.vinted.fr/items/7840113841-jeans?referrer=catalog
# 2025-12-30 16:18:38,843 WARNING GET https://www.vinted.fr/items/7840113841-jeans?referrer=catalog -> status 429
# 2025-12-30 16:18:38,845 WARNING Failed product fetch: https://www.vinted.fr/items/7840113841-jeans?referrer=catalog
# 2025-12-30 16:18:38,846 INFO Fetching product: https://www.vinted.fr/items/7839360809-pantalon-jean-troue?referrer=catalog
# 2025-12-30 16:18:38,983 WARNING GET https://www.vinted.fr/items/7839360809-pantalon-jean-troue?referrer=catalog -> status 429
# 2025-12-30 16:18:38,984 WARNING Failed product fetch: https://www.vinted.fr/items/7839360809-pantalon-jean-troue?referrer=catalog
# 2025-12-30 16:18:38,985 INFO Fetching product: https://www.vinted.fr/items/7840442880-pantalon-la-brigada-international?referrer=catalog
# 2025-12-30 16:18:39,382 WARNING GET https://www.vinted.fr/items/7840442880-pantalon-la-brigada-international?referrer=catalog -> status 429
# 2025-12-30 16:18:39,383 WARNING Failed product fetch: https://www.vinted.fr/items/7840442880-pantalon-la-brigada-international?referrer=catalog
# 2025-12-30 16:18:39,385 INFO Fetching product: https://www.vinted.fr/items/7840426972-jean-stradivarius-d98?referrer=catalog
# 2025-12-30 16:18:40,063 WARNING GET https://www.vinted.fr/items/7840426972-jean-stradivarius-d98?referrer=catalog -> status 429
# 2025-12-30 16:18:40,065 WARNING Failed product fetch: https://www.vinted.fr/items/7840426972-jean-stradivarius-d98?referrer=catalog
# 2025-12-30 16:18:40,066 INFO Fetching product: https://www.vinted.fr/items/7839844205-jean-femme-noir-kaporal-taille-36?referrer=catalog
# 2025-12-30 16:18:40,190 WARNING GET https://www.vinted.fr/items/7839844205-jean-femme-noir-kaporal-taille-36?referrer=catalog -> status 429
# 2025-12-30 16:18:40,191 WARNING Failed product fetch: https://www.vinted.fr/items/7839844205-jean-femme-noir-kaporal-taille-36?referrer=catalog
# 2025-12-30 16:18:40,192 INFO Fetching product: https://www.vinted.fr/items/7839507539-jean-taille-40?referrer=catalog
# 2025-12-30 16:18:40,304 WARNING GET https://www.vinted.fr/items/7839507539-jean-taille-40?referrer=catalog -> status 429
# 2025-12-30 16:18:40,306 WARNING Failed product fetch: https://www.vinted.fr/items/7839507539-jean-taille-40?referrer=catalog
# 2025-12-30 16:18:40,308 INFO Fetching product: https://www.vinted.fr/items/7840440277-jean-bleu-large?referrer=catalog
# 2025-12-30 16:18:40,429 WARNING GET https://www.vinted.fr/items/7840440277-jean-bleu-large?referrer=catalog -> status 429
# 2025-12-30 16:18:40,431 WARNING Failed product fetch: https://www.vinted.fr/items/7840440277-jean-bleu-large?referrer=catalog
# 2025-12-30 16:18:40,432 INFO Fetching product: https://www.vinted.fr/items/7840221166-pantalon-gris?referrer=catalog
# 2025-12-30 16:18:40,543 WARNING GET https://www.vinted.fr/items/7840221166-pantalon-gris?referrer=catalog -> status 429
# 2025-12-30 16:18:40,545 WARNING Failed product fetch: https://www.vinted.fr/items/7840221166-pantalon-gris?referrer=catalog
# 2025-12-30 16:18:40,547 INFO Fetching product: https://www.vinted.fr/items/7839453552-pantalon-droit-velours-cotele?referrer=catalog
# 2025-12-30 16:18:40,690 WARNING GET https://www.vinted.fr/items/7839453552-pantalon-droit-velours-cotele?referrer=catalog -> status 429
# 2025-12-30 16:18:40,692 WARNING Failed product fetch: https://www.vinted.fr/items/7839453552-pantalon-droit-velours-cotele?referrer=catalog
# 2025-12-30 16:18:40,693 INFO Fetching product: https://www.vinted.fr/items/7839549385-jeans-mom-pull-bear?referrer=catalog
# 2025-12-30 16:18:40,823 WARNING GET https://www.vinted.fr/items/7839549385-jeans-mom-pull-bear?referrer=catalog -> status 429
# 2025-12-30 16:18:40,826 WARNING Failed product fetch: https://www.vinted.fr/items/7839549385-jeans-mom-pull-bear?referrer=catalog
# 2025-12-30 16:18:40,827 INFO Fetching product: https://www.vinted.fr/items/7839072116-jean-slim?referrer=catalog
# 2025-12-30 16:18:40,947 WARNING GET https://www.vinted.fr/items/7839072116-jean-slim?referrer=catalog -> status 429
# 2025-12-30 16:18:40,949 WARNING Failed product fetch: https://www.vinted.fr/items/7839072116-jean-slim?referrer=catalog
# 2025-12-30 16:18:40,950 INFO Fetching product: https://www.vinted.fr/items/7839081296-jean-neuf?referrer=catalog
# 2025-12-30 16:18:41,335 WARNING GET https://www.vinted.fr/items/7839081296-jean-neuf?referrer=catalog -> status 429
# 2025-12-30 16:18:41,337 WARNING Failed product fetch: https://www.vinted.fr/items/7839081296-jean-neuf?referrer=catalog
# 2025-12-30 16:18:41,339 INFO Fetching product: https://www.vinted.fr/items/7839065734-jeans-bleu-zara?referrer=catalog
# 2025-12-30 16:18:41,631 WARNING GET https://www.vinted.fr/items/7839065734-jeans-bleu-zara?referrer=catalog -> status 429
# 2025-12-30 16:18:41,633 WARNING Failed product fetch: https://www.vinted.fr/items/7839065734-jeans-bleu-zara?referrer=catalog
# 2025-12-30 16:18:41,634 INFO Fetching product: https://www.vinted.fr/items/7840665240-jean-homme?referrer=catalog
# 2025-12-30 16:18:42,072 WARNING GET https://www.vinted.fr/items/7840665240-jean-homme?referrer=catalog -> status 429
# 2025-12-30 16:18:42,074 WARNING Failed product fetch: https://www.vinted.fr/items/7840665240-jean-homme?referrer=catalog
# 2025-12-30 16:18:42,076 INFO Fetching product: https://www.vinted.fr/items/7839829776-jean-gemo?referrer=catalog
# 2025-12-30 16:18:42,274 WARNING GET https://www.vinted.fr/items/7839829776-jean-gemo?referrer=catalog -> status 429
# 2025-12-30 16:18:42,276 WARNING Failed product fetch: https://www.vinted.fr/items/7839829776-jean-gemo?referrer=catalog
# 2025-12-30 16:18:42,277 INFO Fetching product: https://www.vinted.fr/items/7840402825-hm-blue-flared-high-waisted-jean?referrer=catalog
# 2025-12-30 16:18:42,636 WARNING GET https://www.vinted.fr/items/7840402825-hm-blue-flared-high-waisted-jean?referrer=catalog -> status 429
# 2025-12-30 16:18:42,638 WARNING Failed product fetch: https://www.vinted.fr/items/7840402825-hm-blue-flared-high-waisted-jean?referrer=catalog
# 2025-12-30 16:18:42,640 INFO Fetching product: https://www.vinted.fr/items/7839883999-jean-large-zara-1213-ans?referrer=catalog
# 2025-12-30 16:18:43,197 WARNING GET https://www.vinted.fr/items/7839883999-jean-large-zara-1213-ans?referrer=catalog -> status 429
# 2025-12-30 16:18:43,199 WARNING Failed product fetch: https://www.vinted.fr/items/7839883999-jean-large-zara-1213-ans?referrer=catalog
# 2025-12-30 16:18:43,200 INFO Fetching product: https://www.vinted.fr/items/7839960719-jean-noir?referrer=catalog
# 2025-12-30 16:18:43,453 WARNING GET https://www.vinted.fr/items/7839960719-jean-noir?referrer=catalog -> status 429
# 2025-12-30 16:18:43,454 WARNING Failed product fetch: https://www.vinted.fr/items/7839960719-jean-noir?referrer=catalog
# 2025-12-30 16:18:43,455 INFO Fetching product: https://www.vinted.fr/items/7840059810-ensemble-en-jean-raye?referrer=catalog
# 2025-12-30 16:18:43,674 WARNING GET https://www.vinted.fr/items/7840059810-ensemble-en-jean-raye?referrer=catalog -> status 429
# 2025-12-30 16:18:43,677 WARNING Failed product fetch: https://www.vinted.fr/items/7840059810-ensemble-en-jean-raye?referrer=catalog
# 2025-12-30 16:18:43,679 INFO Fetching product: https://www.vinted.fr/items/7839646814-jean-droit-bershka?referrer=catalog
# 2025-12-30 16:18:43,797 WARNING GET https://www.vinted.fr/items/7839646814-jean-droit-bershka?referrer=catalog -> status 429
# 2025-12-30 16:18:43,798 WARNING Failed product fetch: https://www.vinted.fr/items/7839646814-jean-droit-bershka?referrer=catalog
# 2025-12-30 16:18:43,800 INFO Fetching listing page 2: https://www.vinted.fr/vetements?search_text=jean&page=2
# 2025-12-30 16:18:50,907 INFO Found 0 new product links on page 2
# 2025-12-30 16:18:50,909 INFO Scraped 50 products
# 2025-12-30 16:18:50,913 INFO Saved 50 items to vinted_products.csv and vinted_products.jsonl
