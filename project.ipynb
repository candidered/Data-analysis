# %%
import time
import random
import logging
import csv  
import json
import re
from urllib.parse import urljoin, urlparse, parse_qs, urlencode
from typing import List, Dict, Optional, Set
import requests
from bs4 import BeautifulSoup

# vinted_scraper.py
# Requires: requests, bs4
# Optional: selenium (if dynamic rendering required)


# Reuse notebook variables if present
BASE_URL = 'https://www.vinted.fr'
START_URL = f'{BASE_URL}/vetements?search_text=jean'
USER_AGENT = 'Mozilla/5.0 (compatible; VintedScraper/1.0; +https://example.com/bot)'
session = requests.Session()
session.headers.update({'User-Agent': USER_AGENT})
rp = None
REQUEST_DELAY = (1.0, 3.0)
MAX_PAGES = 50
LOG_LEVEL = 20
OUTPUT_CSV = 'vinted_products.csv'
OUTPUT_JSONL = 'vinted_products.jsonl'

logging.basicConfig(level=LOG_LEVEL, format='%(asctime)s %(levelname)s %(message)s')
logger = logging.getLogger(__name__)
session.headers.update({'User-Agent': USER_AGENT})

# %%
def polite_get(url: str, timeout: int = 15) -> Optional[requests.Response]:
    """Fetch URL while respecting robots.txt (if rp provided) and random delay."""
    if rp is not None:
        try:
            if not rp.can_fetch(USER_AGENT, url):
                logger.warning("Blocked by robots.txt: %s", url)
                return None
        except Exception:
            # If robotparser misconfigured, continue but log
            logger.debug("robots parser error for %s", url)
    try:
        resp = session.get(url, timeout=timeout)
        if resp.status_code == 200:
            # polite delay
            time.sleep(random.uniform(*REQUEST_DELAY))
            return resp
        logger.warning("GET %s -> status %s", url, resp.status_code)
    except Exception as e:
        logger.exception("Request failed: %s", e)
    return None


def make_page_url(base: str, page: int) -> str:
    """Add or replace page param in a URL's query string."""
    parsed = urlparse(base)
    qs = parse_qs(parsed.query)
    qs['page'] = [str(page)]
    new_query = urlencode({k: v[0] for k, v in qs.items()})
    return parsed._replace(query=new_query).geturl()


PRODUCT_URL_PATTERNS = [r'/items/', r'/item/', r'/v/', r'/listing/']


def looks_like_product(href: str) -> bool:
    if not href:
        return False
    parsed = urlparse(href)
    path = parsed.path
    for p in PRODUCT_URL_PATTERNS:
        if re.search(p, path):
            return True
    return False


def extract_links_from_listing(html: str) -> Set[str]:
    soup = BeautifulSoup(html, 'html.parser')
    links = set()
    for a in soup.find_all('a', href=True):
        href = a['href']
        # normalize relative URLs
        full = urljoin(BASE_URL, href)
        if looks_like_product(full):
            # strip fragment and query params that aren't needed
            u = full.split('#')[0]
            links.add(u)
    return links


def parse_product_page(html: str, url: str) -> Dict:
    soup = BeautifulSoup(html, 'html.parser')
    data = {'url': url}

    # Try JSON-LD first
    try:
        for script in soup.find_all('script', type='application/ld+json'):
            try:
                j = json.loads(script.string or '')
            except Exception:
                continue
            # j might be a list
            items = j if isinstance(j, list) else [j]
            for item in items:
                if isinstance(item, dict) and item.get('@type', '').lower() == 'product':
                    data['title'] = item.get('name') or data.get('title')
                    data['description'] = item.get('description') or data.get('description')
                    images = item.get('image')
                    if isinstance(images, list):
                        data['images'] = images
                    elif isinstance(images, str):
                        data['images'] = [images]
                    offers = item.get('offers') or {}
                    if isinstance(offers, dict):
                        data['price'] = offers.get('price')
                        data['currency'] = offers.get('priceCurrency')
                    # found JSON-LD product; good enough
                    break
            if 'title' in data:
                break
    except Exception:
        logger.debug("JSON-LD parse error", exc_info=True)

    # Fallback to meta tags
    if 'title' not in data:
        og_title = soup.find('meta', property='og:title')
        if og_title and og_title.get('content'):
            data['title'] = og_title['content']
    if 'description' not in data:
        og_desc = soup.find('meta', property='og:description')
        if og_desc and og_desc.get('content'):
            data['description'] = og_desc['content']
    if 'images' not in data:
        og_image = soup.find('meta', property='og:image')
        if og_image and og_image.get('content'):
            data['images'] = [og_image['content']]

    # price meta
    if 'price' not in data:
        price_meta = soup.find('meta', attrs={'property': 'product:price:amount'})
        if price_meta and price_meta.get('content'):
            data['price'] = price_meta['content']
    if 'currency' not in data:
        cur_meta = soup.find('meta', attrs={'property': 'product:price:currency'})
        if cur_meta and cur_meta.get('content'):
            data['currency'] = cur_meta['content']

    # Extract textual details heuristically
    try:
        # item id from url digits
        m = re.search(r'(\d{4,})', url)
        if m:
            data['item_id'] = m.group(1)
    except Exception:
        pass

    # images from gallery
    imgs = []
    for img in soup.select('img'):
        src = img.get('src') or img.get('data-src') or img.get('data-lazy-src')
        if src and src.startswith('http'):
            imgs.append(src)
    if imgs:
        data.setdefault('images', imgs)

    # Seller info heuristics
    seller = {}
    seller_a = soup.find('a', href=re.compile(r'/membre/|/member/'))
    if seller_a:
        seller['name'] = seller_a.get_text(strip=True)
        seller['url'] = urljoin(BASE_URL, seller_a['href'])
    if seller:
        data['seller'] = seller

    # Additional fields by selectors (best-effort)
    # price text
    if 'price' not in data:
        price_el = soup.select_one('[data-testid="price"], .price, .ProductPrice, .item-price')
        if price_el:
            data['price'] = price_el.get_text(strip=True)
    # size, brand, condition - try to find label/value pairs
    attrs = {}
    for li in soup.select('.item-attributes li, .details-list li, .CharacteristicList li'):
        txt = li.get_text(separator=' ', strip=True)
        if ':' in txt:
            k, v = txt.split(':', 1)
            attrs[k.strip().lower()] = v.strip()
    if attrs:
        data.setdefault('attributes', attrs)
    # Extract brand and condition from attributes
    for key in ['marque', 'brand']:
        if key in attrs:
            data['brand'] = attrs[key]
            break
    for key in ['état', 'etat', 'condition']:
        if key in attrs:
            data['condition'] = attrs[key]
            break

    data['scraped_at'] = time.strftime('%Y-%m-%dT%H:%M:%SZ', time.gmtime())
    return data


def save_results(items: List[Dict], csv_path: str = OUTPUT_CSV, jsonl_path: str = OUTPUT_JSONL):
    # JSONL
    with open(jsonl_path, 'w', encoding='utf-8') as f:
        for it in items:
            f.write(json.dumps(it, ensure_ascii=False) + '\n')
    # CSV (flatten some fields)
    fieldnames = [
        'item_id', 'title', 'price', 'currency', 'url', 'seller', 'images', 'description', 'brand', 'condition', 'scraped_at'
    ]
    with open(csv_path, 'w', newline='', encoding='utf-8') as f:
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writeheader()
        for it in items:
            row = {
                'item_id': it.get('item_id'),
                'title': it.get('title'),
                'price': it.get('price'),
                'currency': it.get('currency'),
                'url': it.get('url'),
                'seller': it.get('seller', {}).get('name') if isinstance(it.get('seller'), dict) else '',
                'images': ';'.join(it.get('images', [])) if it.get('images') else '',
                'description': it.get('description', '')[:1000],
                'brand': it.get('brand'),
                'condition': it.get('condition'),
                'scraped_at': it.get('scraped_at'),
            }
            writer.writerow(row)


def scrape_vinted(start_url: str = START_URL, max_pages: int = MAX_PAGES) -> List[Dict]:
    all_products = []
    seen_urls = set()
    for page in range(1, max_pages + 1):
        page_url = make_page_url(start_url, page)
        logger.info("Fetching listing page %d: %s", page, page_url)
        resp = polite_get(page_url)
        if not resp:
            logger.info("Stopping: failed to fetch page %d", page)
            break
        links = extract_links_from_listing(resp.text)
        links = [l for l in links if l not in seen_urls]
        logger.info("Found %d new product links on page %d", len(links), page)
        if not links:
            # nothing new, stop
            break
        for prod_url in links:
            seen_urls.add(prod_url)
            logger.info("Fetching product: %s", prod_url)
            presp = polite_get(prod_url)
            if not presp:
                logger.warning("Failed product fetch: %s", prod_url)
                continue
            pdata = parse_product_page(presp.text, prod_url)
            all_products.append(pdata)
        # quick stop if reached many products (optional)
    logger.info("Scraped %d products", len(all_products))
    return all_products

# %%
items = scrape_vinted()
save_results(items)
logger.info("Saved %d items to %s and %s", len(items), OUTPUT_CSV, OUTPUT_JSONL)
# Out:
# 2025-12-19 10:44:20,971 INFO Fetching listing page 1: https://www.vinted.fr/vetements?search_text=jean&page=1
# 2025-12-19 10:44:25,968 INFO Found 96 new product links on page 1
# 2025-12-19 10:44:25,969 INFO Fetching product: https://www.vinted.fr/items/7786583829-jean-ultra-baggy-noir-patchwork-motif-leopard-streetwear-2000-style-japan-m?referrer=catalog
# 2025-12-19 10:44:29,801 INFO Fetching product: https://www.vinted.fr/items/7788446935-jean-patte-deph-36?referrer=catalog
# 2025-12-19 10:44:32,657 INFO Fetching product: https://www.vinted.fr/items/7787065698-jean-femme-pimkie-taille-34?referrer=catalog
# 2025-12-19 10:44:34,718 INFO Fetching product: https://www.vinted.fr/items/7787033480-jeans?referrer=catalog
# 2025-12-19 10:44:36,725 INFO Fetching product: https://www.vinted.fr/items/7787776012-jean-flare-noir-stradivarius?referrer=catalog
# 2025-12-19 10:44:40,353 INFO Fetching product: https://www.vinted.fr/items/7787443203-jean-bleu-patte-delephant-zara-40?referrer=catalog
# 2025-12-19 10:44:44,065 INFO Fetching product: https://www.vinted.fr/items/7788558633-jeans-droit-zara?referrer=catalog
# 2025-12-19 10:44:47,826 INFO Fetching product: https://www.vinted.fr/items/7788292476-pantalon-large?referrer=catalog
# 2025-12-19 10:44:52,728 INFO Fetching product: https://www.vinted.fr/items/7787137357-jean-taille-basse?referrer=catalog
# 2025-12-19 10:44:54,935 INFO Fetching product: https://www.vinted.fr/items/7787916085-lot-deux-jeans-taille-38?referrer=catalog
# 2025-12-19 10:44:58,078 INFO Fetching product: https://www.vinted.fr/items/7787594733-jean-femme?referrer=catalog
# 2025-12-19 10:45:01,528 INFO Fetching product: https://www.vinted.fr/items/7787695016-jean-bleu?referrer=catalog
# 2025-12-19 10:45:03,876 INFO Fetching product: https://www.vinted.fr/items/7787019229-jean-gris?referrer=catalog
# 2025-12-19 10:45:05,803 INFO Fetching product: https://www.vinted.fr/items/7787713924-pantalon?referrer=catalog
# 2025-12-19 10:45:17,809 INFO Fetching product: https://www.vinted.fr/items/7788233133-jean-large?referrer=catalog
# 2025-12-19 10:45:20,666 INFO Fetching product: https://www.vinted.fr/items/7786680914-jeans-fille?referrer=catalog
# 2025-12-19 10:45:22,619 INFO Fetching product: https://www.vinted.fr/items/7786885030-jean-taille-basse?referrer=catalog
# 2025-12-19 10:45:25,089 INFO Fetching product: https://www.vinted.fr/items/7788550727-jean-zara?referrer=catalog
# 2025-12-19 10:45:28,299 INFO Fetching product: https://www.vinted.fr/items/7788459194-pantalon-jambe-large?referrer=catalog
# 2025-12-19 10:45:30,474 INFO Fetching product: https://www.vinted.fr/items/7787435412-jean-slim-droit-denim-straight?referrer=catalog
# 2025-12-19 10:45:32,798 INFO Fetching product: https://www.vinted.fr/items/7788266895-jeans-large?referrer=catalog
# 2025-12-19 10:45:35,939 INFO Fetching product: https://www.vinted.fr/items/7788278403-jeans-fille?referrer=catalog
# 2025-12-19 10:45:38,746 INFO Fetching product: https://www.vinted.fr/items/7786513217-style-streetwear-y2k-jean-baggy-noir-night-vin-broderies-florales-coupe-large?referrer=catalog
# 2025-12-19 10:45:41,650 INFO Fetching product: https://www.vinted.fr/items/7787845000-pantalon-coupe-droit-noir-femme?referrer=catalog
# 2025-12-19 10:45:44,800 INFO Fetching product: https://www.vinted.fr/items/7787177673-jeans-evase-avec-details?referrer=catalog
# 2025-12-19 10:45:46,730 INFO Fetching product: https://www.vinted.fr/items/7788327776-jean-wide?referrer=catalog
# 2025-12-19 10:45:50,004 INFO Fetching product: https://www.vinted.fr/items/7786894545-jeans-fille?referrer=catalog
# 2025-12-19 10:45:53,363 INFO Fetching product: https://www.vinted.fr/items/7787385007-jean-gris-bzb-32?referrer=catalog
# 2025-12-19 10:45:55,620 INFO Fetching product: https://www.vinted.fr/items/7787587112-jeans-bebe-fille?referrer=catalog
# 2025-12-19 10:45:59,151 INFO Fetching product: https://www.vinted.fr/items/7787708971-jean-clair?referrer=catalog
# 2025-12-19 10:46:01,825 INFO Fetching product: https://www.vinted.fr/items/7787471826-jean-taille-haute?referrer=catalog
# 2025-12-19 10:46:04,259 INFO Fetching product: https://www.vinted.fr/items/7787727262-jean-zara?referrer=catalog
# 2025-12-19 10:46:07,749 INFO Fetching product: https://www.vinted.fr/items/7787548227-jean-evase?referrer=catalog
# 2025-12-19 10:46:11,198 INFO Fetching product: https://www.vinted.fr/items/7787856537-jean-troue?referrer=catalog
# 2025-12-19 10:46:14,903 INFO Fetching product: https://www.vinted.fr/items/7786997346-jeans-pour-garcon-de-15-a-2-ans?referrer=catalog
# 2025-12-19 10:46:17,134 INFO Fetching product: https://www.vinted.fr/items/7788032574-jean-oversize?referrer=catalog
# 2025-12-19 10:46:20,180 INFO Fetching product: https://www.vinted.fr/items/7787601722-jean-zara?referrer=catalog
# 2025-12-19 10:46:23,593 INFO Fetching product: https://www.vinted.fr/items/7787078944-jeans-coupe-baggy-bleu-hm-taille-146cm?referrer=catalog
# 2025-12-19 10:46:26,228 INFO Fetching product: https://www.vinted.fr/items/7777939664-pantalon-coupe-droite-stretch-gris-noir-delave-femme-38?referrer=catalog
# 2025-12-19 10:46:28,254 INFO Fetching product: https://www.vinted.fr/items/7787845491-jean-bleu-clair?referrer=catalog
# 2025-12-19 10:46:31,815 INFO Fetching product: https://www.vinted.fr/items/7787790593-jean-zara?referrer=catalog
# 2025-12-19 10:46:35,792 INFO Fetching product: https://www.vinted.fr/items/7788339501-jean-mom-noir?referrer=catalog
# 2025-12-19 10:46:38,511 INFO Fetching product: https://www.vinted.fr/items/7787807269-jean-36?referrer=catalog
# 2025-12-19 10:46:41,539 INFO Fetching product: https://www.vinted.fr/items/7787542212-jean-gris?referrer=catalog
# 2025-12-19 10:46:43,892 INFO Fetching product: https://www.vinted.fr/items/7787074239-jean-large?referrer=catalog
# 2025-12-19 10:46:46,403 INFO Fetching product: https://www.vinted.fr/items/7788209681-pantalon-noir?referrer=catalog
# 2025-12-19 10:46:48,875 INFO Fetching product: https://www.vinted.fr/items/7788457369-jean-pattes-def-taille-basse?referrer=catalog
# 2025-12-19 10:46:51,875 INFO Fetching product: https://www.vinted.fr/items/7787656979-jean-large?referrer=catalog
# 2025-12-19 10:46:54,212 INFO Fetching product: https://www.vinted.fr/items/7787642993-jean-zara?referrer=catalog
# 2025-12-19 10:46:57,584 INFO Fetching product: https://www.vinted.fr/items/7786817042-jean-mango?referrer=catalog
# 2025-12-19 10:47:00,368 INFO Fetching product: https://www.vinted.fr/items/7788348661-jeans-2732-esprit?referrer=catalog
# 2025-12-19 10:47:03,024 INFO Fetching product: https://www.vinted.fr/items/7788329593-jean-mom-fit?referrer=catalog
# 2025-12-19 10:47:05,296 INFO Fetching product: https://www.vinted.fr/items/7788189991-jean-noir-taille-haute?referrer=catalog
# 2025-12-19 10:47:07,525 INFO Fetching product: https://www.vinted.fr/items/7787805207-jean-evase?referrer=catalog
# 2025-12-19 10:47:10,598 INFO Fetching product: https://www.vinted.fr/items/7788275291-jeans-shein-femme-taille-haute?referrer=catalog
# 2025-12-19 10:47:13,259 INFO Fetching product: https://www.vinted.fr/items/7787330041-jean-bershka-taille-basse-coupe-droite-taille-10-12-ans?referrer=catalog
# 2025-12-19 10:47:15,324 INFO Fetching product: https://www.vinted.fr/items/7788635083-jean-evase-bleu-delave-details-coutures-et-ceinture-strass-taille-36?referrer=catalog
# 2025-12-19 10:47:18,314 INFO Fetching product: https://www.vinted.fr/items/7787076214-jean-shein?referrer=catalog
# 2025-12-19 10:47:20,478 INFO Fetching product: https://www.vinted.fr/items/7788093313-jean-mom-promod-taille-40?referrer=catalog
# 2025-12-19 10:47:23,944 INFO Fetching product: https://www.vinted.fr/items/7786724045-pantalon-coeur-large?referrer=catalog
# 2025-12-19 10:47:26,143 INFO Fetching product: https://www.vinted.fr/items/7788161390-jean-fille?referrer=catalog
# 2025-12-19 10:47:28,496 INFO Fetching product: https://www.vinted.fr/items/7788113231-jean-large?referrer=catalog
# 2025-12-19 10:47:30,777 INFO Fetching product: https://www.vinted.fr/items/7787590383-pantalon-wide-leg-hm?referrer=catalog
# 2025-12-19 10:47:32,879 INFO Fetching product: https://www.vinted.fr/items/7788378303-lot-2-jeans-fille-56-ans-h-et-m?referrer=catalog
# 2025-12-19 10:47:34,787 INFO Fetching product: https://www.vinted.fr/items/7788415730-jeans-zara-taille-haute?referrer=catalog
# 2025-12-19 10:47:37,723 INFO Fetching product: https://www.vinted.fr/items/7787000981-jean-noir?referrer=catalog
# 2025-12-19 10:47:40,942 INFO Fetching product: https://www.vinted.fr/items/7787648915-jean-baggy?referrer=catalog
# 2025-12-19 10:47:44,461 INFO Fetching product: https://www.vinted.fr/items/7788264348-jean-monoprix-neuf-4-ans?referrer=catalog
# 2025-12-19 10:47:47,381 INFO Fetching product: https://www.vinted.fr/items/7787729944-jean-droit-taille-44?referrer=catalog
# 2025-12-19 10:47:50,382 INFO Fetching product: https://www.vinted.fr/items/7788359775-jeans-neuf-jamais-porte-taille-34?referrer=catalog
# 2025-12-19 10:47:53,726 INFO Fetching product: https://www.vinted.fr/items/7787596745-pantalon-gris-taille-basse?referrer=catalog
# 2025-12-19 10:47:55,879 INFO Fetching product: https://www.vinted.fr/items/7788389642-jean-skinny-zara?referrer=catalog
# 2025-12-19 10:47:59,164 INFO Fetching product: https://www.vinted.fr/items/7787083596-jean-femme-pimkie-taille-34?referrer=catalog
# 2025-12-19 10:48:01,701 INFO Fetching product: https://www.vinted.fr/items/7787482143-jean-bleu-clair-reglable-gemo-18-mois?referrer=catalog
# 2025-12-19 10:48:04,084 INFO Fetching product: https://www.vinted.fr/items/7788122426-pantalon-pattes-delephant?referrer=catalog
# 2025-12-19 10:48:07,296 INFO Fetching product: https://www.vinted.fr/items/7788319302-vetement-enfant-jean?referrer=catalog
# 2025-12-19 10:48:09,469 INFO Fetching product: https://www.vinted.fr/items/7788129813-jean-baggy?referrer=catalog
# 2025-12-19 10:48:12,665 INFO Fetching product: https://www.vinted.fr/items/7788269479-lot-de-jegging-et-skinny?referrer=catalog
# 2025-12-19 10:48:16,784 INFO Fetching product: https://www.vinted.fr/items/7787489226-jean-femme-hm-taille-34-noir?referrer=catalog
# 2025-12-19 10:48:19,894 INFO Fetching product: https://www.vinted.fr/items/7787859593-jeans-noir-delave?referrer=catalog
# 2025-12-19 10:48:23,589 INFO Fetching product: https://www.vinted.fr/items/7788136387-jean-pimkie-32?referrer=catalog
# 2025-12-19 10:48:26,213 INFO Fetching product: https://www.vinted.fr/items/7786910054-jeans-pull-and-bear?referrer=catalog
# 2025-12-19 10:48:28,944 INFO Fetching product: https://www.vinted.fr/items/7786536637-ndeg238-jean-femme-deco-au-niveau-des-poches-avant?referrer=catalog
# 2025-12-19 10:48:33,702 INFO Fetching product: https://www.vinted.fr/items/7787449258-jean-pull-bear?referrer=catalog
# 2025-12-19 10:48:36,052 INFO Fetching product: https://www.vinted.fr/items/7787747569-jeans-strass?referrer=catalog
# 2025-12-19 10:48:38,109 INFO Fetching product: https://www.vinted.fr/items/7788551558-pantalon-wide-leg-mango?referrer=catalog
# 2025-12-19 10:48:41,517 INFO Fetching product: https://www.vinted.fr/items/7787521085-jean-troue?referrer=catalog
# 2025-12-19 10:48:44,585 INFO Fetching product: https://www.vinted.fr/items/7788284283-jean-bleu-clair-hm-11-12-ans?referrer=catalog
# 2025-12-19 10:48:48,179 INFO Fetching product: https://www.vinted.fr/items/7786643856-jean-flare?referrer=catalog
# 2025-12-19 10:48:50,323 INFO Fetching product: https://www.vinted.fr/items/7788218642-jean-bleu-fonce?referrer=catalog
# 2025-12-19 10:48:53,290 INFO Fetching product: https://www.vinted.fr/items/7786433557-jean-gris?referrer=catalog
# 2025-12-19 10:48:56,428 INFO Fetching product: https://www.vinted.fr/items/7788156490-jean-filles?referrer=catalog
# 2025-12-19 10:48:59,301 INFO Fetching product: https://www.vinted.fr/items/7788221765-jeans-taille-haute?referrer=catalog
# 2025-12-19 10:49:01,634 INFO Fetching product: https://www.vinted.fr/items/7787498820-jean-droit-bleu?referrer=catalog
# 2025-12-19 10:49:05,411 INFO Fetching product: https://www.vinted.fr/items/7787470405-jean-bleu-18-mois-cerise-lovely-poches-coeur?referrer=catalog
# 2025-12-19 10:49:09,231 INFO Fetching product: https://www.vinted.fr/items/7787540333-jean-large-okaidi?referrer=catalog
# 2025-12-19 10:49:13,144 INFO Fetching listing page 2: https://www.vinted.fr/vetements?search_text=jean&page=2
# 2025-12-19 10:49:16,842 INFO Found 0 new product links on page 2
# 2025-12-19 10:49:16,845 INFO Scraped 96 products
# 2025-12-19 10:49:16,895 INFO Saved 96 items to vinted_products.csv and vinted_products.jsonl
